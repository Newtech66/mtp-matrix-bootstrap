# %%
import cvxpy as cp
import numpy as np
from scipy.sparse import csr_array
import scipy as sp
from sympy.matrices import Matrix
import matplotlib.pyplot as plt
from collections import Counter
from common import SiteBasis

# %%
def basis_commutator(o1, o2):
    commutation_table = [
        [(0, ''),(0, ''),(0, ''),(0, '')],
        [(0, ''),(0, ''),(2j, 'Z'),(-2j, 'Y')],
        [(0, ''),(-2j, 'Z'),(0, ''),(2j, 'X')],
        [(0, ''),(2j, 'Y'),(-2j, 'X'),(0, '')],
    ]
    return commutation_table['IXYZ'.find(o1)]['IXYZ'.find(o2)]

def basis_anticommutator(o1, o2):
    anticommutation_table = [
        [(2, 'I'),(2, 'X'),(2, 'Y'),(2, 'Z')],
        [(2, 'X'),(2, 'I'),(0, ''),(0, '')],
        [(2, 'Y'),(0, ''),(2, 'I'),(0, '')],
        [(2, 'Z'),(0, ''),(0, ''),(2, 'I')],
    ]
    return anticommutation_table['IXYZ'.find(o1)]['IXYZ'.find(o2)]

def basis_product(o1, o2):
    product_table = [
        [(1, 'I'),(1, 'X'),(1, 'Y'),(1, 'Z')],
        [(1, 'X'),(1, 'I'),(1j, 'Z'),(-1j, 'Y')],
        [(1, 'Y'),(-1j, 'Z'),(1, 'I'),(1j, 'X')],
        [(1, 'Z'),(1j, 'Y'),(-1j, 'X'),(1, 'I')],
    ]
    return product_table['IXYZ'.find(o1)]['IXYZ'.find(o2)]

def anticommutator(word1, word2):
    if len(word1) != len(word2):
        raise ValueError(f'{word1} and {word2} do not have same length')
    if len(word1) == 1:
        return [basis_anticommutator(word1, word2)]
    expression = []
    e_1 = commutator(word1[0],word2[0])
    e_2 = commutator(word1[1:], word2[1:])
    e_3 = anticommutator(word1[0], word2[0])
    e_4 = anticommutator(word1[1:],word2[1:])
    for c1, o1 in e_1:
        for c2, o2 in e_2:
            expression.append((0.5 * c1 * c2, o1 + o2))
    for c1, o1 in e_3:
        for c2, o2 in e_4:
            expression.append((0.5 * c1 * c2, o1 + o2))
    return expression

def commutator(word1: str, word2: str):
    if len(word1) != len(word2):
        raise ValueError(f'{word1} and {word2} do not have same length')
    if len(word1) == 1:
        return [basis_commutator(word1, word2)]
    expression = []
    e_1 = commutator(word1[0],word2[0])
    e_2 = anticommutator(word1[1:], word2[1:])
    e_3 = anticommutator(word1[0], word2[0])
    e_4 = commutator(word1[1:],word2[1:])
    for c1, o1 in e_1:
        for c2, o2 in e_2:
            expression.append((0.5 * c1 * c2, o1 + o2))
    for c1, o1 in e_3:
        for c2, o2 in e_4:
            expression.append((0.5 * c1 * c2, o1 + o2))
    return expression

def product(word1, word2):
    if len(word1) != len(word2):
        raise ValueError(f'{word1} and {word2} do not have same length')
    word = []
    coeff = 1
    for o1, o2 in zip(word1, word2):
        c, op = basis_product(o1, o2)
        word.append(op)
        coeff *= c
    return (coeff, ''.join(word))

# %% [markdown]
# <h2>Thermal Transverse Field Ising:</h2>

# %%
def schwinger_dyson(hamil: list, word1: str):
    expression = []
    for coeff, w in hamil:
        terms = commutator(w, word1)
        for c, op in terms:
            if len(op) != len(word1):
                continue
            if not np.isclose(np.abs(coeff * c), 0):
                expression.append((op, coeff * c))
    return expression

def normalization(basis, L, B):
    return [B[basis.rank('I'*L)] == 1]

def beta_independent_constraints(basis, B, L, hamil):
    constraints = []
    constraints.extend(normalization(basis, L, B))
    row_ind, col_ind, data = [], [], []
    numc = 0
    n = basis.size()
    def add_terms(terms):
        nonlocal numc
        new_row = 0
        cnt = 0
        for term in terms:
            cnt += 1
            new_row = 1
            col_ind.append(basis.rank(term[0]))
            data.append(term[1])
            row_ind.append(numc)
        numc += new_row
    for word in basis._ops:
        add_terms(schwinger_dyson(hamil, word))
    if len(col_ind) > 0:
        P = csr_array((data, (row_ind, col_ind)), (numc, n))
        constraints.append(P @ B == 0)
    return constraints

def test_kms(basis, H, hamil, beta, k):
    ops = basis._ops
    n = len(ops)
    constraints = []
    def get_A_term(i, j):
        coeff, word = product(ops[i], ops[j])
        return coeff * H[basis.rank(word)]
    A = cp.bmat([[get_A_term(i, j) for j in range(n)] for i in range(n)])
    def get_C_term(i, j):
        expression = 0
        termsd = Counter()
        for coeff, w in hamil:
            terms = commutator(w, ops[j])
            for c, op in terms:
                if len(op) != len(w):
                    continue
                c2, op2 = product(ops[i], op)
                termsd[op2] += coeff * c * c2
        for op, coeff in termsd.items():
            if np.isclose(np.abs(coeff),0):
                continue
            expression = expression + coeff * H[basis.rank(op)]
        return expression
    C = cp.bmat([[get_C_term(i, j) for j in range(n)] for i in range(n)])
    T = 2**(-k) * beta * C
    B = cp.conj(A)
    Zs = [B] + [cp.Variable((n,n),f'Z_{i}',hermitian=True) for i in range(1, k + 1)]
    for i in range(k):
        constraints.append(cp.bmat([[Zs[i], Zs[i+1]],
                                    [Zs[i+1], A]]) >> 0)
    al, be, ga, de = -1, 5, 2, 4
    b = (be*de - ga) / (be - al)
    a = de - b
    constraints.append(cp.bmat([[Zs[k] + al*A + a*T, np.sqrt(a*b) * T],
                                [np.sqrt(a*b) * T, Zs[k] + be*A + b*T]]) >> 0)
    # # large x
    # v = 0.3
    # al, be, ga, de = -1.2, 15, 6.3, 10
    # b = (be*de - ga) / (be - al)
    # a = de - b
    # constraints.append(cp.bmat([[Zs[k] + al*A + a*(T+v*A), np.sqrt(a*b) * (T+v*A)],
    #                             [np.sqrt(a*b) * (T+v*A), Zs[k] + be*A + b*(T+v*A)]]) >> 0)
    # # small x
    # u, v = -0.3, 0.13
    # al, be, ga, de = -1-u, 5+u, 2+4*u, 4
    # b = (be*de - ga) / (be - al)
    # a = de - b
    # constraints.append(cp.bmat([[Zs[k] + al*A + a*(T+v*A), np.sqrt(a*b) * (T+v*A)],
    #                             [np.sqrt(a*b) * (T+v*A), Zs[k] + be*A + b*(T+v*A)]]) >> 0)
    return constraints

# %%
def construct_hamil(L, h):
    hamil = []
    for i in range(L):
        t1 = None
        if i<L-1:
            t1 = 'I'*i + 'XX' + 'I'*(L-i-2)
        else:
            t1 = 'X' + 'I'*(L-2) + 'X'
        t2 = 'I'*i+'Z'+'I'*(L-i-1)
        hamil.extend([(-1, t1), (-h, t2)])
    if L == 2:
        hamil = [(-h, 'IZ'), (-h, 'ZI'), (-1, 'XX')]
    return hamil

def construct_problem(L, h, k):
    basis = SiteBasis(L)
    B = cp.Variable(basis.size())
    hamil = construct_hamil(L, h)
    beta = cp.Parameter(nonneg = True)
    constraints = beta_independent_constraints(basis, B, L, hamil)
    constraints.extend(test_kms(basis, B, hamil, beta, k))
    energy = -1 * L * B[basis.rank('XX'+'I'*(L-2))] - h * L * B[basis.rank('Z'+'I'*(L-1))]
    if L == 2:
        energy = -1 * B[basis.rank('XX')] - h * 2 * B[basis.rank('Z'+'I'*(L-1))]
    minprob = cp.Problem(cp.Minimize(energy), constraints)
    maxprob = cp.Problem(cp.Maximize(energy), constraints)
    return beta, minprob, maxprob

def solve_energy(betas, beta, minprob, maxprob):
    mins,maxs = np.zeros_like(betas), np.zeros_like(betas)
    for i, val in enumerate(betas):
        beta.value = val
        print(f'Solving for T={1/val}, i={i}:')
        E_min = minprob.solve(accept_unknown=True, verbose=True)
        E_max = maxprob.solve(accept_unknown=True, verbose=True)
        print(f'\tE_min = {E_min}')
        print(f'\tE_max = {E_max}')
        mins[i], maxs[i] = E_min, E_max
    return mins, maxs

# %%
L, h, k = 5, 1, 1
beta, minprob, maxprob = construct_problem(L, h, k)
# Out:
# c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\problems\problem.py:164: UserWarning: Constraint #2 contains too many subexpressions. Consider vectorizing your CVXPY code to speed up compilation.
#   warnings.warn(f"Constraint #{i} contains too many subexpressions. "
# c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\problems\problem.py:164: UserWarning: Constraint #3 contains too many subexpressions. Consider vectorizing your CVXPY code to speed up compilation.
#   warnings.warn(f"Constraint #{i} contains too many subexpressions. "

# %%
betas = 1/np.linspace(0.01, 4, num = 1)
mins, maxs = solve_energy(betas, beta, minprob, maxprob)
# Out:
# Solving for T=0.01, i=0:
# ===============================================================================
#                                      CVXPY
#                                      v1.6.6
# ===============================================================================
# (CVXPY) Jun 20 04:23:29 PM: Your problem has 18632 variables, 148103 constraints, and 1 parameters.
# (CVXPY) Jun 20 04:23:33 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jun 20 04:23:33 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) Jun 20 04:23:33 PM: Your problem is compiled with the CPP canonicalization backend.
# (CVXPY) Jun 20 04:23:40 PM: Compiling problem (target solver=MOSEK).
# (CVXPY) Jun 20 04:23:40 PM: Reduction chain: Complex2Real -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Jun 20 04:23:40 PM: Applying reduction Complex2Real
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 betas = 1/np.linspace(0.01, 4, num = 1)
# ----> 2 mins, maxs = solve_energy(betas, beta, minprob, maxprob)
#
# Cell In[16], line 34, in solve_energy(betas, beta, minprob, maxprob)
#      32 beta.value = val
#      33 print(f'Solving for T={1/val}, i={i}:')
# ---> 34 E_min = minprob.solve(accept_unknown=True, verbose=True)
#      35 E_max = maxprob.solve(accept_unknown=True, verbose=True)
#      36 print(f'\tE_min = {E_min}')
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\problems\problem.py:600, in Problem.solve(self, *args, **kwargs)
#     597         raise ValueError(
#     598             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     599     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 600 return solve_func(self, *args, **kwargs)
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\problems\problem.py:1176, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1173         self.unpack(chain.retrieve(soln))
#    1174         return self.value
# -> 1176 data, solving_chain, inverse_data = self.get_problem_data(
#    1177     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1178 )
#    1180 if verbose:
#    1181     print(_NUM_SOLVER_STR)
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\problems\problem.py:796, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     793     s.LOGGER.info(
#     794              'Compiling problem (target solver=%s).', solver_name)
#     795     s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 796 data, inverse_data = solving_chain.apply(self, verbose)
#     797 safe_to_cache = (
#     798     isinstance(data, dict)
#     799     and s.PARAM_PROB in data
#     800     and not any(isinstance(reduction, EvalParams)
#     801                 for reduction in solving_chain.reductions)
#     802 )
#     803 self._compilation_time = time.time() - start
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\reductions\chain.py:76, in Chain.apply(self, problem, verbose)
#      74     if verbose:
#      75         s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76     problem, inv = r.apply(problem)
#      77     inverse_data.append(inv)
#      78 return problem, inverse_data
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\reductions\complex2real\complex2real.py:66, in Complex2Real.apply(self, problem)
#      62 constrs = []
#      63 for constraint in problem.constraints:
#      64     # real2imag maps variable id to a potential new variable
#      65     # created for the imaginary part.
# ---> 66     real_constrs, imag_constrs = self.canonicalize_tree(
#      67         constraint, inverse_data.real2imag, leaf_map)
#      68     if isinstance(real_constrs, list):
#      69         constrs.extend(real_constrs)
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\reductions\complex2real\complex2real.py:167, in Complex2Real.canonicalize_tree(self, expr, real2imag, leaf_map)
#     165 imag_args = []
#     166 for arg in expr.args:
# --> 167     real_arg, imag_arg = self.canonicalize_tree(arg, real2imag, leaf_map)
#     168     real_args.append(real_arg)
#     169     imag_args.append(imag_arg)
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\reductions\complex2real\complex2real.py:167, in Complex2Real.canonicalize_tree(self, expr, real2imag, leaf_map)
#     165 imag_args = []
#     166 for arg in expr.args:
# --> 167     real_arg, imag_arg = self.canonicalize_tree(arg, real2imag, leaf_map)
#     168     real_args.append(real_arg)
#     169     imag_args.append(imag_arg)
#
#     [... skipping similar frames: Complex2Real.canonicalize_tree at line 167 (7 times)]
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\reductions\complex2real\complex2real.py:167, in Complex2Real.canonicalize_tree(self, expr, real2imag, leaf_map)
#     165 imag_args = []
#     166 for arg in expr.args:
# --> 167     real_arg, imag_arg = self.canonicalize_tree(arg, real2imag, leaf_map)
#     168     real_args.append(real_arg)
#     169     imag_args.append(imag_arg)
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\reductions\complex2real\complex2real.py:170, in Complex2Real.canonicalize_tree(self, expr, real2imag, leaf_map)
#     168         real_args.append(real_arg)
#     169         imag_args.append(imag_arg)
# --> 170     real_out, imag_out = self.canonicalize_expr(expr, real_args,
#     171                                                 imag_args, real2imag,
#     172                                                 leaf_map)
#     173 return real_out, imag_out
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\reductions\complex2real\complex2real.py:180, in Complex2Real.canonicalize_expr(self, expr, real_args, imag_args, real2imag, leaf_map)
#     178 if len(expr.args) == 0 and expr in leaf_map:
#     179     return leaf_map[expr]
# --> 180 result = elim_cplx_methods[type(expr)](expr, real_args, imag_args, real2imag)
#     181 if len(expr.args) == 0:
#     182     leaf_map[expr] = result
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\reductions\complex2real\canonicalizers\aff_canon.py:37, in separable_canon(expr, real_args, imag_args, real2imag)
#      35         elif imag_args[idx] is None:
#      36             imag_args[idx] = Constant(np.zeros(real_args[idx].shape))
# ---> 37     outputs = (expr.copy(real_args), expr.copy(imag_args))
#      38 return outputs
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\atoms\affine\add_expr.py:103, in AddExpression.copy(self, args, id_objects)
#     101     args = [self]
#     102 copy = type(self).__new__(type(self))
# --> 103 copy.__init__(args)
#     104 return copy
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\atoms\affine\add_expr.py:33, in AddExpression.__init__(self, arg_groups)
#      32 def __init__(self, arg_groups: Iterable[Expression]) -> None:
# ---> 33     super(AddExpression, self).__init__(*arg_groups)
#      34     self.args = []
#      35     for group in arg_groups:
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\atoms\atom.py:51, in Atom.__init__(self, *args)
#      49 self.args = [Atom.cast_to_const(arg) for arg in args]
#      50 self.validate_arguments()
# ---> 51 self._shape = self.shape_from_args()
#      52 if not s.ALLOW_ND_EXPR and len(self._shape) > 2:
#      53     raise ValueError("Atoms must be at most 2D.")
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\atoms\affine\add_expr.py:41, in AddExpression.shape_from_args(self)
#      38 def shape_from_args(self) -> Tuple[int, ...]:
#      39     """Returns the (row, col) shape of the expression.
#      40     """
# ---> 41     return u.shape.sum_shapes([arg.shape for arg in self.args])
#
# File c:\mtp\my-work\.venv\Lib\site-packages\cvxpy\utilities\shape.py:49, in sum_shapes(shapes)
#      27 def sum_shapes(shapes: List[Tuple[int, ...]]) -> Tuple[int, ...]:
#      28     """
#      29     Give the shape resulting from summing a list of shapes.
#      30
#    (...)     47         If the shapes are not compatible.
#      48     """
# ---> 49     return np.broadcast_shapes(*shapes)
#
# File c:\mtp\my-work\.venv\Lib\site-packages\numpy\lib\_stride_tricks_impl.py:473, in broadcast_shapes(*args)
#     433 @set_module('numpy')
#     434 def broadcast_shapes(*args):
#     435     """
#     436     Broadcast the input shapes into a single shape.
#     437
#    (...)    471     (5, 6, 7)
#     472     """
# --> 473     arrays = [np.empty(x, dtype=_size0_dtype) for x in args]
#     474     return _broadcast_shape(*arrays)
#
# KeyboardInterrupt:

# %%
data = np.load('ising-3-1-3.npz', allow_pickle=True)
betas = data['betas']
mins = data['mins']
maxs = data['maxs']

# %%
plt.fill_between(1/betas, mins, maxs, alpha = 0.5, zorder=2)
plt.plot(1/betas, mins,c ='red',linestyle='--',label='lower bound',zorder=3)
plt.plot(1/betas, maxs,c ='blue',linestyle='--',label='upper bound',zorder=3)
plt.xlabel('T')
plt.ylabel('E')
plt.title(f'(L, h, k) = ({2}, {h}, {k}) transverse Ising model')
plt.legend()
plt.grid(zorder=1)
plt.savefig(f'ising-{2}-{h}-{k}.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# <h2>Manual basis reduction:</h2>

# %%
class BasisReduction():
    def __init__(self, A, b):
        self._A = A.copy()
        self._b = b.copy()
        self._Arref, self._brref = Matrix(A).rref_rhs(Matrix(b))
        self._pivots = Matrix(A).rref()[1]
        self._free = sorted(list(set(range(A.shape[1])) - set(self._pivots))) # This is with the original numbering
        self._sz = len(self._free)
        self._reductions = [[Counter(), 0.0] for _ in range(A.shape[1])]
        self._init_free() # Initialize mappings for free variables
        self._generate_reductions() # Initialize mappings for pivot variables

    def _init_free(self):
        for i, p in enumerate(self._free):
            self._reductions[p][0][i] += 1.0
            self._reductions[p][1] = 0.0
    
    def _generate_reductions(self):
        crow = len(self._pivots) - 1
        for pcol in reversed(self._pivots):
            # Create mapping
            self._reductions[pcol][1] += np.double(self._brref[crow])
            for ccol in range(pcol + 1, self._A.shape[1]):
                if not np.isclose(self._Arref[crow, ccol], 0.0):
                    coeff = np.double(-self._Arref[crow, ccol]) # minus sign to transfer to other side of equality
                    self._reductions[pcol][1] += coeff * self._reductions[ccol][1]
                    for freew, c in self._reductions[ccol][0].items():
                        self._reductions[pcol][0][freew] += coeff * c
            # Update currow
            crow -= 1

    def size(self):
        return self._sz

    def reduce(self, p):
        # Return a mapping of the p-th element of the original basis
        # to a linear combination + constant offset of the new basis
        # Remember to take care of the numbering
        return self._reductions[p]

# %%
def beta_independent_constraints(basis, hamil):
    row_ind, col_ind, data = [0], [0], [1.0j]
    numc = 1
    n = basis.size()
    def add_terms(terms):
        nonlocal numc
        new_row = 0
        cnt = 0
        for term in terms:
            cnt += 1
            new_row = 1
            col_ind.append(basis.rank(term[0]))
            data.append(term[1])
            row_ind.append(numc)
        numc += new_row
    for word in basis._ops:
        add_terms(schwinger_dyson(hamil, word))
    A = np.zeros((numc, n))
    if len(col_ind) > 0:
        for r, c, d in zip(row_ind, col_ind, data):
            A[r, c] += np.imag(d)
    b = np.zeros((numc, 1))
    b[0, 0] = 1.0
    return A, b

def kms(basis, redbas, H, hamil, beta, k):
    ops = basis._ops
    n = len(ops)
    constraints = []
    def get_A_term(i, j):
        coeff, word = product(ops[i], ops[j])
        rew, const = redbas.reduce(basis.rank(word))
        expression = coeff * const
        for p, c in rew.items():
            c2 = coeff * c
            # print(expression, 'coeff', coeff, 'c', c, 'c2', c2, 'p', p)
            expression = expression + c2 * H[p]
        return expression
    A = cp.bmat([[get_A_term(i, j) for j in range(n)] for i in range(n)])
    def get_C_term(i, j):
        expression = 0
        termsd = Counter()
        for coeff, w in hamil:
            terms = commutator(w, ops[j])
            for c, op in terms:
                if len(op) != len(w):
                    continue
                c2, op2 = product(ops[i], op)
                termsd[op2] += coeff * c * c2
        for op, coeff in termsd.items():
            if np.isclose(np.abs(coeff), 0):
                continue
            rew, const = redbas.reduce(basis.rank(op))
            subexpression = coeff * const
            for p, c in rew.items():
                subexpression = subexpression + coeff * c * H[p]
            # print(subexpression, 'coeff', coeff, 'exp', expression)
            # print(coeff * subexpression)
            expression = expression + subexpression
        return expression
    C = cp.bmat([[get_C_term(i, j) for j in range(n)] for i in range(n)])
    T = 2**(-k) * beta * C
    B = cp.conj(A)
    Zs = [B] + [cp.Variable((n,n),f'Z_{i}',hermitian=True) for i in range(1, k + 1)]
    for i in range(k):
        constraints.append(cp.bmat([[Zs[i], Zs[i+1]],
                                    [Zs[i+1], A]]) >> 0)
    al, be, ga, de = -1, 5, 2, 4
    b = (be*de - ga) / (be - al)
    a = de - b
    constraints.append(cp.bmat([[Zs[k] + al*A + a*T, np.sqrt(a*b) * T],
                                [np.sqrt(a*b) * T, Zs[k] + be*A + b*T]]) >> 0)
    return constraints

# %%
def construct_hamil(L, h):
    hamil = []
    for i in range(L):
        t1 = None
        if i<L-1:
            t1 = 'I'*i + 'XX' + 'I'*(L-i-2)
        else:
            t1 = 'X' + 'I'*(L-2) + 'X'
        t2 = 'I'*i+'Z'+'I'*(L-i-1)
        hamil.extend([(-1, t1), (-h, t2)])
    if L == 2:
        hamil = [(-h, 'IZ'), (-h, 'ZI'), (-1, 'XX')]
    return hamil

def construct_problem(L, h, k):
    basis = SiteBasis(L)
    hamil = construct_hamil(L, h)
    beta = cp.Parameter(nonneg = True)
    A, b = beta_independent_constraints(basis, hamil)
    redbas = BasisReduction(A, b)
    B = cp.Variable(redbas.size())
    constraints = []
    constraints.extend(kms(basis, redbas, B, hamil, beta, k))
    energy = 0
    for coeff, word in hamil:
        # rew will be a dict with mapping {rank in reduced basis: coefficient}
        p2 = basis.rank(word)
        rew, const = redbas.reduce(p2)
        energy += coeff * const
        for p, c2 in rew.items():
            energy += coeff * c2 * B[p]
    minprob = cp.Problem(cp.Minimize(energy), constraints)
    maxprob = cp.Problem(cp.Maximize(energy), constraints)
    return beta, minprob, maxprob

def solve_energy(betas, beta, minprob, maxprob):
    mins,maxs = np.zeros_like(betas), np.zeros_like(betas)
    for i, val in enumerate(betas):
        beta.value = val
        print(f'Solving for T={1/val}, i={i}:')
        E_min = minprob.solve(accept_unknown=True)
        E_max = maxprob.solve(accept_unknown=True)
        print(f'\tE_min = {E_min}')
        print(f'\tE_max = {E_max}')
        mins[i], maxs[i] = E_min, E_max
    return mins, maxs

# %%
L, h, k = 4, 1, 3
beta, minprob, maxprob = construct_problem(L, h, k)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
betas = 1/np.linspace(0.01, 4, num = 20)
mins, maxs = solve_energy(betas, beta, minprob, maxprob)
# Out:
# Solving for T=0.01, i=0:

# %%
plt.fill_between(1/betas, mins, maxs, alpha = 0.5, zorder=2)
plt.plot(1/betas, mins,c ='red',linestyle='--',label='lower bound',zorder=3)
plt.plot(1/betas, maxs,c ='blue',linestyle='--',label='upper bound',zorder=3)
plt.xlabel('T')
plt.ylabel('E')
plt.title(f'(L, h, k) = ({L}, {h}, {k}) transverse Ising model')
plt.legend()
plt.grid(zorder=1)
plt.show()
